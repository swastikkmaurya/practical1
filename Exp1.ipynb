# %% [markdown]
# <a href="https://colab.research.google.com/github/swastikkmaurya/practical1/blob/main/Exp1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#exp 1 : Introduction to python
#swastik
#2507012314

# %%
a= "Apple"
b="cherry"
c="orange"
print(a,b,c)
# Out:
# Apple cherry orange

# %%
x,y,z="apple","cherry","orange"
print(x,y,z,sep="\n")
# Out:
# apple
# cherry
# orange

# %%
x,y,w,z= 2,2.5,"Swastik",True
print(x,y,w,z,sep="\n")
print(type(x),type(y),type(w),type(z),sep="\n")
# Out:
# 2
# 2.5
# Swastik
# True
# <class 'int'>
# <class 'float'>
# <class 'str'>
# <class 'bool'>

# %%
a,b=10,5
print("sum=",a+b)
print("sub=",a-b)
print("mult=",a*b)
print("div=",a/b)
print("Power=",a**b)
# Out:
# sum= 15
# sub= 5
# mult= 50
# div= 2.0
# Power= 100000

# %%
a=int(input("Enter the value of a="))
b=int(input("Enter the value of b="))
print(" Sum=",a+b,"\n","sub=",a-b,"\n","Mult=",a*b,"\n","Div=",a/b,"\n","Power=",a**b)
# Out:
# Enter the value of a=23
# Enter the value of b=2
#  Sum= 25
#  sub= 21
#  Mult= 46
#  Div= 11.5
#  Power= 529

# %%
import math
r=float(input("Enter the value of r="))
print("Area of the Circle =",(r**2)*math.pi)
# Out:
# Enter the value of r=2
# Area of the Circle = 12.566370614359172

# %%
import math
a=math.log10(10)
print("The value of Log variable=",a)
# Out:
# The value of Log variable= 1.0

# %%
a=int(input("Enter the value of a="))
b=int(input("Enter the value of b="))
if a>b:
  print("A is greater than b ")
else:
  print("B is greater than A")
# Out:
# Enter the value of a=3
# Enter the value of b=4
# B is greater than A
